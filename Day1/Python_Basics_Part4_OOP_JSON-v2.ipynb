# %% [markdown]
# # Python Basics Part 4: OOP & JSON
# This notebook introduces **Object-Oriented Programming (OOP)** for organizing code and the **JSON** library for handling data interchange.

# %% [markdown]
# ## 1. Classes and Objects (OOP Basics)
# OOP allows you to bundle data (attributes) and behaviors (methods) together. Think of a **Class** as a blueprint and an **Object** as the actual thing built from that blueprint.

# %%
class Dog:
    # The __init__ method initializes the object's attributes
    def __init__(self, name, breed):
        self.name = name
        self.breed = breed

    # A method is a function inside a class
    def bark(self):
        return f"{self.name} says Woof!"

# Creating objects (instances of the class)
my_dog = Dog("Buddy", "Golden Retriever")
another_dog = Dog("Rex", "German Shepherd")

print(f"My dog's name is {my_dog.name}.")
print(my_dog.bark())
print(another_dog.bark())
# Out:
# My dog's name is Buddy.
# Buddy says Woof!
# Rex says Woof!

# %% [markdown]
# ## 2. Working with JSON
# JSON (JavaScript Object Notation) is a standard format for data exchange. Python's `json` library converts between Python dictionaries and JSON strings.

# %%
import json

# A Python Dictionary
person_dict = {
    "name": "John",
    "age": 30,
    "city": "New York",
    "has_license": True
}

# Convert Dictionary to JSON String (Serialization)
json_string = json.dumps(person_dict, indent=4)
print("JSON String Output:")
print(json_string)

# Convert JSON String back to Dictionary (Deserialization)
new_dict = json.loads(json_string)
print("\nBack to Python Dictionary:")
print(new_dict["name"])
# Out:
# JSON String Output:
# {
#     "name": "John",
#     "age": 30,
#     "city": "New York",
#     "has_license": true
# }
#
# Back to Python Dictionary:
# John

# %% [markdown]
# ## 3. Reading and Writing JSON Files
# You can save and load data directly from `.json` files.

# %%
data = {"project": "Python Basics", "status": "Completed"}

# Writing JSON to a file
with open("data.json", "w") as f:
    json.dump(data, f)

# Reading JSON from a file
with open("data.json", "r") as f:
    loaded_data = json.load(f)
    print("Data loaded from file:")
    print(loaded_data)
# Out:
# Data loaded from file:
# {'project': 'Python Basics', 'status': 'Completed'}
