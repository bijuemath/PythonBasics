# %% [markdown]
# # Data Science Basics: NumPy and Pandas Tutorial
# This notebook covers the essentials of **NumPy** (Numerical Python) and **Pandas** (Data Analysis Library), the two most important libraries for data manipulation in Python.

# %% [markdown]
# ## 1. NumPy Essentials
# NumPy is used for working with numerical arrays. It is much faster than standard Python lists for mathematical operations.

# %%
import numpy as np

# Creating a 1D array
arr = np.array([1, 2, 3, 4, 5])
print(f"1D Array: {arr}")

# Creating a 2D array (Matrix)
matrix = np.array([[1, 2, 3], [4, 5, 6]])
print(f"Matrix:\n{matrix}")

# Useful functions
print(f"Mean: {np.mean(arr)}")
print(f"Standard Deviation: {np.std(arr)}")
print(f"Shape of matrix: {matrix.shape}")
# Out:
# 1D Array: [1 2 3 4 5]
# Matrix:
# [[1 2 3]
#  [4 5 6]]
# Mean: 3.0
# Standard Deviation: 1.4142135623730951
# Shape of matrix: (2, 3)

# %% [markdown]
# ## 2. Pandas Essentials
# Pandas introduces the **DataFrame**, which is like a spreadsheet or SQL table inside Python.

# %%
import pandas as pd

# Creating a DataFrame from a dictionary
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 40],
    'City': ['New York', 'London', 'Paris', 'Berlin']
}

df = pd.DataFrame(data)
print("Full DataFrame:")
print(df)

# Basic Data Analysis
print("\nSummary Statistics:")
print(df.describe())

# Selecting a column
print("\nAges only:")
print(df['Age'])

# %% [markdown]
# ## 3. Filtering and Selecting Data
# One of the most powerful features of Pandas is filtering data based on conditions.

# %%
# Filter: People older than 30
older_than_30 = df[df['Age'] > 30]
print("People older than 30:")
print(older_than_30)

# Selecting specific rows and columns using .iloc (index location)
print("\nFirst two rows, first two columns:")
print(df.iloc[0:2, 0:2])
